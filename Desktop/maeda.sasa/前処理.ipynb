# %%
import pandas as pd
import numpy as np
import csv
import codecs

# %%
with codecs.open("201610.csv", "r", "Shift-JIS", "ignore") as file:
    df = pd.read_table(file, delimiter=",")
    df = pd.DataFrame(df)
    print(df)
# Out:
#    2016年10月 交通量月報   上り 名･豊･衣 交通量      Unnamed: 1 Unnamed: 2       Unnamed: 3  \
# 0                            NaN             NaN        NaN              NaN
# 1                            NaN               1          2                3
# 2                             場所  日進\r\r〜\r\r長久手   長久手\r\r△  ロング\r\rランプ\r\r△
# 3                             項目            総交通量       総交通量             総交通量
# 4                             単位             台/h        台/h              台/h
# 5                         01日(土)            6466       3493             2973
# 6                         02日(日)            6100       3216             2884
# 7                         03日(月)            5678       3057             2621
# 8                         04日(火)            6458       3316             3142
# 9                         05日(水)            6071       3232             2839
# 10                        06日(木)            6812       3493             3319
# ...

# %%
df.columns
# Out:
# Index(['2016年10月 交通量月報   上り 名･豊･衣 交通量', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
